# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaine-eng/SQL-Server-Management-Studio/blob/main/SQL_SERVER_Cria%C3%A7%C3%A3o_de_Tabelas_com_scripts_conceitos_de_chaves_prim%C3%A1ria_e_estrangeira.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Chave primária - Primary Key**

# %% [markdown]
# A **chave primária** ou **Primary key (PK)** é o identificador único de um registro na tabela. Pode ser constituída de um campo (chave simples) ou pela combinação de dois ou mais campos (chave composta), de tal maneira que não existam dois registros com o mesmo valor de chave primária.
#
# A constraint Primary Key (chave primaria), não permite valores nulos e impõe a exclusividade de linhas.
#
# O exemplo de uma chave primária de uma pessoa é o seu CPF.

# %% [markdown]
# # **2. Chave estrangeira**

# %% [markdown]
# O conceito de chave estrangeira ou Foreign Key - FK se refere ao tipo de relacionamento entre distintas tabelas de dados do banco de dados. A finalidade da chave estrangeira é garantir a integridade dos dados referenciais, pois apenas serão permitidos valores que supostamente vão aparecer na base de dados.

# %% [markdown]
# Veja o exemplo abaixo:
#
# Temos relacionados três tabelas, em destaque indicamos  as chaves primárias e estrangeiras.

# %% [markdown]
# **Figura 01 - Projeto do curso relacionar a tabela alunos/ cursos com as turmas**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **3. Criação de tabela com scripts**

# %% [markdown]
# Vamos iniciar o projeto abrindo o SQL Server e criando o script para a tabela Alunos através do comando CREATE TABLE. o id_aluno é uma chave primária.

# %% [markdown]
# **Figura 02 - Criação da tabela Alunos**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O comando DROP TABLE é usado quando você deseja excluir a tabela. foi adicionado ao código apenas como comentário. Porém pode ser usado a qualquer momento, lembrando que ao selecionar a linha e clica em executar e realizado apenas aquela parte do comando.

# %% [markdown]
# **Figura 03 - Comando DROP TABLE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Figura 04 - Criação da tabela Situação**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Figura 05 - Criação da tabela Cursos**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Figura 06 - Criação da tabela Turmas**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Figura 07 - Criação da tabela Registo_Presença**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Figura 09 - Registro do comando DROP TABLE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Se você deseja saber um pouco mais sobre tipos de dados, veja o site da microsoft que encontrará tudo bem explicado.
#
# https://docs.microsoft.com/pt-br/sql/t-sql/data-types/data-types-transact-sql?view=sql-server-ver16

# %% [markdown]
# # **Referência**

# %% [markdown]
# Aula- SQL Server - Alessandro Trovato.
#
# https://www.youtube.com/watch?v=Yvw60m0E9D8&list=PL7iAT8C5wumpQWB8AFW7CwK2nlzh8ZdP9&index=5

# %% [markdown]
# ****
