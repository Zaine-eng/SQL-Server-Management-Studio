# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaine-eng/SQL-Server-Management-Studio/blob/main/SQL_Server_Cria%C3%A7%C3%A3o_do_Banco_de_Dados_e_propriedades_dele_aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Criação de um Banco de Dados**

# %% [markdown]
# - O banco de dados foi construido utilizando o SQL Server Management Studio e chamaremos de - **SQL_DB_1**.
#
# Veja abaixo o passo a passo desta construção:

# %% [markdown]
# ## **1.1. Visualização inicial do programa**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **1.2. Criação do banco de dados**

# %% [markdown]
# 1. Estamos criando um novo banco de dados;
# 2. Nomeamos como SQL_BD_1.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Inicialmente vamos criar uma tabela rápida, apenas para entender um pouco nossos recursos.

# %% [markdown]
# ## **1.3. Tabela**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Abaixo primeiramente foi feito os campos da tabela, depois salvamos e adicionamos um nome.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As vezes a tabela não aparece imediatamente, atualize com F5.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Usando o SELECT para visualizar a tabela criada.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2. Propriedades dos Bancos de Dados**

# %% [markdown]
# Para visualizar as propriedades da tabela - *dimensoes_Cursos* criada basta clicar com o botão direito sobre a tabela e ir até propriedades, isto vai lhe mostrar como toda tabela foi criada, levando em consideração os itens como geral, as permissões, controle de operações, entre outros.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Referência**

# %% [markdown]
# Aula- SQL Server - Alessandro Trovato.
#
# https://www.youtube.com/watch?v=SLY_ZcNYjIY&list=PL7iAT8C5wumpQWB8AFW7CwK2nlzh8ZdP9&index=4

# %% [markdown]
# ---
